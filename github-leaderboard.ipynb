# %%
import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd

# %%
df=pd.read_csv('namelist.csv')

# %%
df.head()
# Out:
#   Course_Code  Student_Name                      github_link        remark
# 0    COMM7780   CAI Xuejiao     https://github.com/PepperCai       student
# 1    COMM7780  CHEN Mengjie      https://github.com/DidoChan       student
# 2    COMM7780       CHEN Ye    https://github.com/Shinonomee       student
# 3    COMM7780     DU Jiawei  https://github.com/jasmine-dudu       student
# 4    COMM7780    FENG Yujin   https://github.com/Catmint1215  class helper

# %%
namelist=[]
for name in df['github_link']:
    namelist.append(name)

# %%
namelist
# Out:
# ['https://github.com/PepperCai',
#  'https://github.com/DidoChan',
#  'https://github.com/Shinonomee',
#  'https://github.com/jasmine-dudu',
#  'https://github.com/Catmint1215',
#  'https://github.com/FLYSTEPHEN',
#  'https://github.com/guminyi',
#  'https://github.com/trista520',
#  'https://github.com/Rita0719',
#  'https://github.com/Wong-Ming',
#  'https://github.com/ConnorLi96',
#  'https://github.com/18408532',
#  'https://github.com/graceyit',
#  'https://github.com/clairelau0108',
#  'https://github.com/hakutoccino',
#  'https://github.com/JIEYI22',
#  'https://github.com/coolxu8888',
#  'https://github.com/AlexZenghuashan',
#  'https://github.com/CelineTsang',
#  'https://github.com/zacharyzeng',
#  'https://github.com/iiiJenny',
#  'https://github.com/ZhangNingNina/',
#  'https://github.com/CathyChang1996',
#  'https://github.com/elusiveburglar',
#  'https://github.com/maggie0114',
#  'https://github.com/efncij',
#  'https://github.com/ClioLI',
#  'https://github.com/CCCCCecilia',
#  'https://github.com/Alana-LI',
#  'https://github.com/shiyuning0987',
#  'https://github.com/ivywang958',
#  'https://github.com/kaiwenxu94',
#  'https://github.com/warrior960812',
#  'https://github.com/Yang9305',
#  'https://github.com/lullabymia',
#  'https://github.com/yaonuan1995',
#  'https://github.com/18426425',
#  'https://github.com/Zmh951010',
#  'https://github.com/ZHANGboh',
#  'https://github.com/ZhangHuimin97',
#  'https://github.com/zhangjingwei0512',
#  'https://github.com/NicoleZZC',
#  'https://github.com/niegung',
#  'https://github.com/hupili',
#  'https://github.com/ChicoXYC',
#  'https://github.com/SerenaQYHuang']

# %%
activities=[]

for url in namelist:
    r=requests.get(url).text
    data=BeautifulSoup(r,"html.parser")
    information=data.find_all('rect')
    for j in range(217,len(information)): #start from July 1st
        activity={}
        activity['url'] = url
        activity['data-date'] = information[j]['data-date']
        activity['data-count'] = information[j]['data-count']
        activities.append(activity)

# %%
#activities

# %%
df2 = pd.DataFrame(activities)

# %%
df2.head()
# Out:
#   data-count   data-date                           url
# 0          0  2018-07-01  https://github.com/PepperCai
# 1          0  2018-07-02  https://github.com/PepperCai
# 2          0  2018-07-03  https://github.com/PepperCai
# 3          0  2018-07-04  https://github.com/PepperCai
# 4          0  2018-07-05  https://github.com/PepperCai

# %%
#data-count is not number but string
df3 = df2.groupby('url')['data-count'].agg('sum').reset_index()
df3
# Out:
#                                     url  \
# 0           https://github.com/18408532
# 1           https://github.com/18426425
# 2           https://github.com/Alana-LI
# 3    https://github.com/AlexZenghuashan
# 4        https://github.com/CCCCCecilia
# 5     https://github.com/CathyChang1996
# 6        https://github.com/Catmint1215
# 7        https://github.com/CelineTsang
# 8           https://github.com/ChicoXYC
# 9             https://github.com/ClioLI
# 10        https://github.com/ConnorLi96
# 11          https://github.com/DidoChan
# 12        https://github.com/FLYSTEPHEN
# 13           https://github.com/JIEYI22
# 14         https://github.com/NicoleZZC
# 15         https://github.com/PepperCai
# 16          https://github.com/Rita0719
# 17     https://github.com/SerenaQYHuang
# 18        https://github.com/Shinonomee
# 19         https://github.com/Wong-Ming
# 20          https://github.com/Yang9305
# 21          https://github.com/ZHANGboh
# 22     https://github.com/ZhangHuimin97
# 23    https://github.com/ZhangNingNina/
# 24         https://github.com/Zmh951010
# 25     https://github.com/clairelau0108
# 26        https://github.com/coolxu8888
# 27            https://github.com/efncij
# 28    https://github.com/elusiveburglar
# 29          https://github.com/graceyit
# 30           https://github.com/guminyi
# 31       https://github.com/hakutoccino
# 32            https://github.com/hupili
# 33          https://github.com/iiiJenny
# 34        https://github.com/ivywang958
# 35      https://github.com/jasmine-dudu
# 36        https://github.com/kaiwenxu94
# 37        https://github.com/lullabymia
# 38        https://github.com/maggie0114
# 39           https://github.com/niegung
# 40     https://github.com/shiyuning0987
# 41         https://github.com/trista520
# 42     https://github.com/warrior960812
# 43       https://github.com/yaonuan1995
# 44       https://github.com/zacharyzeng
# 45  https://github.com/zhangjingwei0512
#
#                                            data-count
# 0   0000000000000000000000000000000000000000000000...
# 1   0000000000000000000000000000000000000000000000...
# 2   0000000000000000000000000000000000000000000000...
# 3   0000000000000000000000000000000000000000000000...
# 4   0000000000000000000000000000000000000000000000...
# 5   0000000000000000000000000000100000000000000000...
# 6   0000000000000000000000000000000000000100110000...
# 7   0000000000000000000000000000000000000000000000...
# 8   0000000000000000003526000000151100712102501021...
# 9   0000000000000000000000000000000000000000000000...
# 10  0000000000000000000000000000100000000005005300...
# 11  0000000000000000000000000000000000000000000000...
# 12  0000000000000000000000000000000000000000000000...
# 13  0000000000000000000000000000000000000000000000...
# 14  0000000000000000000000000000000000000000000000...
# 15  0000000000000000000000000000000000000000000000...
# 16  0000000000000000000000000000000000000000000000...
# 17  0000000000000000000000000000000200000000000000...
# 18  0000000000000000000000000000000000000000000000...
# 19  0000000000000000000000000000000000000000000000...
# 20  0000000000000000000000000000000000000000000000...
# 21  0000000000000000000000000000000000000000000000...
# 22  0000000000000000000000000000000000000000000000...
# 23  0000000000000000000000000000000000000000000000...
# 24  0000000000000000000000000000000000000000000000...
# 25  0000000000000000000000000000000000000000000000...
# 26  0000000000000000000000000000000000000000000000...
# 27  0000000000000000000000000000000000000000000000...
# 28  0000000000000000000000000000000000000000000000...
# 29  0000000000000000000000000000000000000000000000...
# 30  0000000000000000000000000000000000000000000000...
# 31  0000000000000000000000000000000000000000000000...
# 32  0000046031820012454013162941501005824001025262...
# 33  0000000000000000000000000000000000000000000000...
# 34  0000000002000000000000000000000007200070000000...
# 35  0000000000000000000000000000000000000000000000...
# 36  0000000000000000000000000000000000000000000000...
# 37  0000000000000000000000000000000000000000000001...
# 38  0000000000000000000000000000000000000000000000...
# 39  0000000000000000000000000000000000000000000000...
# 40  0000000000000000000000000000000000000000000000...
# 41  0000000000000000000000000000000000000000000000...
# 42  0000000000000000000000000000000000000000000000...
# 43  0000000000000000000000000000000000000000000000...
# 44  0000000000000000000000000000010000000000000000...
# 45  0000000000000000000000000000000000000000000000...

# %%
df2['data-count'] = pd.to_numeric(df2['data-count'])
df3 = df2.groupby('url')['data-count'].agg('sum').reset_index()

# %%
df3.rename(columns={'url':'github_link'}, inplace=True)

# %%
#merge two df into one, they must at have one sharing column
df4 = pd.merge(df,df3,how='left',on='github_link')

# %%
df4.sort_values(by=['data-count'],ascending=False)
# Out:
#    Course_Code    Student_Name                          github_link  \
# 43         NaN         Hu Pili            https://github.com/hupili
# 44         NaN        Xu Yucan          https://github.com/ChicoXYC
# 5     COMM7780        GAO Chao        https://github.com/FLYSTEPHEN
# 10    COMM7780       LI Chenxi        https://github.com/ConnorLi96
# 30    JOUR7280      WANG Ziwei        https://github.com/ivywang958
# 34    JOUR7280         YAO Lan        https://github.com/lullabymia
# 12    COMM7780      LIN Yitong          https://github.com/graceyit
# 13    COMM7780        LIU Cong     https://github.com/clairelau0108
# 18    COMM7780     ZENG Sining       https://github.com/CelineTsang
# 15    COMM7780       XIE Jieyi           https://github.com/JIEYI22
# 8     COMM7780       HUANG Xin          https://github.com/Rita0719
# 40    JOUR7280   ZHANG Jingwei  https://github.com/zhangjingwei0512
# 32    JOUR7280          XU Wen     https://github.com/warrior960812
# 16    COMM7780      XU Haotian        https://github.com/coolxu8888
# 2     COMM7780         CHEN Ye        https://github.com/Shinonomee
# 31    JOUR7280       XU Kaiwen        https://github.com/kaiwenxu94
# 17    COMM7780    ZENG Huashan   https://github.com/AlexZenghuashan
# 20    COMM7780      ZHANG Ning          https://github.com/iiiJenny
# 22    COMM7780     ZHANG Shiyu    https://github.com/CathyChang1996
# 36    JOUR7280         YU Qing          https://github.com/18426425
# 24    JOUR7280    JIANG Nixuan        https://github.com/maggie0114
# 28    JOUR7280        LI Yijie          https://github.com/Alana-LI
# 39    JOUR7280    ZHANG Huimin     https://github.com/ZhangHuimin97
# 41    JOUR7280    ZHANG Zichun         https://github.com/NicoleZZC
# 14    COMM7780          LUO Yi       https://github.com/hakutoccino
# 21    COMM7780      ZHANG Ning    https://github.com/ZhangNingNina/
# 29    JOUR7280      SHI Yuning     https://github.com/shiyuning0987
# 4     COMM7780      FENG Yujin       https://github.com/Catmint1215
# 45         NaN  Huang Qiongyao     https://github.com/SerenaQYHuang
# 37    JOUR7280    ZHAI Menghan         https://github.com/Zmh951010
# 23    JOUR7280       HE Wenshu    https://github.com/elusiveburglar
# 9     COMM7780  HUANG Yangming         https://github.com/Wong-Ming
# 0     COMM7780     CAI Xuejiao         https://github.com/PepperCai
# 7     COMM7780      HUANG Ting         https://github.com/trista520
# 35    JOUR7280        YAO Nuan       https://github.com/yaonuan1995
# 19    COMM7780    ZENG Xingjie       https://github.com/zacharyzeng
# 11    COMM7780     LIN Huiqing          https://github.com/18408532
# 27    JOUR7280     LI Shengnan       https://github.com/CCCCCecilia
# 1     COMM7780    CHEN Mengjie          https://github.com/DidoChan
# 6     COMM7780        GU Minyi           https://github.com/guminyi
# 3     COMM7780       DU Jiawei      https://github.com/jasmine-dudu
# 33    JOUR7280        YANG Lin          https://github.com/Yang9305
# 38    JOUR7280     ZHANG Bohan          https://github.com/ZHANGboh
# 26    JOUR7280       LI Mengyu            https://github.com/ClioLI
# 25    JOUR7280     JIANG Weiqi            https://github.com/efncij
# 42         NaN  Cheng Yuanyuan           https://github.com/niegung
#
#           remark  data-count
# 43      lecturer        1078
# 44            TA         575
# 5        student         265
# 10  class helper         164
# 30       student         118
# 34  class helper          96
# 12  class helper          80
# 13       student          72
# 18  class helper          68
# 15       student          66
# 8        student          62
# 40  class helper          60
# 32  class helper          54
# 16       student          51
# 2        student          49
# 31  class helper          48
# 17       student          47
# 20  class helper          46
# 22  class helper          46
# 36       student          46
# 24       student          44
# 28       student          40
# 39       student          39
# 41       student          39
# 14       student          36
# 21       student          35
# 29       student          34
# 4   class helper          32
# 45            TA          32
# 37  class helper          30
# 23       student          29
# 9        student          29
# 0        student          28
# 7        student          24
# 35       student          23
# 19       student          23
# 11       student          23
# 27       student          22
# 1        student          21
# 6        student          20
# 3        student          20
# 33       student          17
# 38       student          16
# 26       student          14
# 25       student          14
# 42        sit in           1

# %%
len(df2)
# Out:
# 6854

# %%
df2.head()
# Out:
#    data-count   data-date                           url
# 0           0  2018-07-01  https://github.com/PepperCai
# 1           0  2018-07-02  https://github.com/PepperCai
# 2           0  2018-07-03  https://github.com/PepperCai
# 3           0  2018-07-04  https://github.com/PepperCai
# 4           0  2018-07-05  https://github.com/PepperCai

# %%
df2.to_csv('activities.csv', index=None)
