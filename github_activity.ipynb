# %%
import pandas as pd
import requests
import time
df=pd.read_csv('activity_counts.csv')

# %%
df
# Out:
#    Course_Code    Student_Name                          github_link  \
# 0          NaN         Hu Pili            https://github.com/hupili
# 1          NaN        Xu Yucan          https://github.com/ChicoXYC
# 2     COMM7780        GAO Chao        https://github.com/FLYSTEPHEN
# 3     COMM7780       LI Chenxi        https://github.com/ConnorLi96
# 4     JOUR7280      WANG Ziwei        https://github.com/ivywang958
# 5     JOUR7280         YAO Lan        https://github.com/lullabymia
# 6     COMM7780      LIN Yitong          https://github.com/graceyit
# 7     COMM7780     ZENG Sining       https://github.com/CelineTsang
# 8     COMM7780        LIU Cong     https://github.com/clairelau0108
# 9     COMM7780       XIE Jieyi           https://github.com/JIEYI22
# 10    COMM7780       HUANG Xin          https://github.com/Rita0719
# 11    JOUR7280   ZHANG Jingwei  https://github.com/zhangjingwei0512
# 12    JOUR7280          XU Wen     https://github.com/warrior960812
# ...

# %%
users = df['github_id'].tolist()

# %%
under_100=users[6:] #filter out students' commits under 100

# %%
under_100
# Out:
# ['graceyit',
#  'CelineTsang',
#  'clairelau0108',
#  'JIEYI22',
#  'Rita0719',
#  'zhangjingwei0512',
#  'warrior960812',
#  'coolxu8888',
#  'Catmint1215',
#  'AlexZenghuashan',
#  'iiiJenny',
#  'Shinonomee',
#  'kaiwenxu94',
#  'CathyChang1996',
#  '18426425',
#  'hakutoccino',
#  'maggie0114',
#  'NicoleZZC',
#  'Alana-LI',
#  'ZhangHuimin97',
#  'Wong-Ming',
#  'ZhangNingNina',
#  'shiyuning0987',
#  'PepperCai',
#  'Zmh951010',
#  'SerenaQYHuang',
#  'elusiveburglar',
#  'yaonuan1995',
#  'zacharyzeng',
#  '18408532',
#  'CCCCCecilia',
#  'trista520',
#  'DidoChan',
#  'guminyi',
#  'jasmine-dudu',
#  'Yang9305',
#  'ClioLI',
#  'ZHANGboh',
#  'efncij',
#  'niegung']

# %%
def get_under_100(user):
    url = 'https://api.github.com/users/{0}/events/public?page=1&per_page=100'.format(user)
    r = requests.get(url,headers={
    'User-Agent':'Mozilla/5.0',
    'Authorization':'token 97daf92ba8b9969bb31166a26cf8c148228a3035',
    'Content-Type':'application/json',
    'method':'GET',
    'Accept':'application/json'
    })
    content = r.json()
    commits = []
    for item in content:
        commit = {}
        commit['users'] = item['actor']['login']
        commit['type'] = item['type']
        commits.append(commit)
    return commits

# %%
all_commits=[]

for user in under_100:
    time.sleep(2)
    try:
        commits = get_under_100(user)
        all_commits.extend(commits)
    except:
        print(user)

# %%
len(all_commits)
# Out:
# 1959

# %%
#scrape divide by user_list, because GitHub api has request limit per hour, around 60.
def get_over_100(url):
    r = requests.get(url,headers={
    'User-Agent':'Mozilla/5.0',
    'Authorization':'token 97daf92ba8b9969bb31166a26cf8c148228a3035',
    'Content-Type':'application/json',
    'method':'GET',
    'Accept':'application/json'
    })
    content = r.json()
    commits = []
    for item in content:
        commit = {}
        commit['users'] = item['actor']['login']
        commit['type'] = item['type']
        commits.append(commit)
    return commits

# %%
over_100=users[0:6]

# %%
over_100
# Out:
# ['hupili', 'ChicoXYC', 'FLYSTEPHEN', 'ConnorLi96', 'ivywang958', 'lullabymia']

# %%
url_list=[]

for user in over_100:
    for i in range(1,12):
        url = 'https://api.github.com/users/{0}/events/public?page={1}&per_page=100'.format(user,i)
        url_list.append(url)

# %%
url_list
# Out:
# ['https://api.github.com/users/hupili/events/public?page=1&per_page=100',
#  'https://api.github.com/users/hupili/events/public?page=2&per_page=100',
#  'https://api.github.com/users/hupili/events/public?page=3&per_page=100',
#  'https://api.github.com/users/hupili/events/public?page=4&per_page=100',
#  'https://api.github.com/users/hupili/events/public?page=5&per_page=100',
#  'https://api.github.com/users/hupili/events/public?page=6&per_page=100',
#  'https://api.github.com/users/hupili/events/public?page=7&per_page=100',
#  'https://api.github.com/users/hupili/events/public?page=8&per_page=100',
#  'https://api.github.com/users/hupili/events/public?page=9&per_page=100',
#  'https://api.github.com/users/hupili/events/public?page=10&per_page=100',
#  'https://api.github.com/users/hupili/events/public?page=11&per_page=100',
#  'https://api.github.com/users/ChicoXYC/events/public?page=1&per_page=100',
#  'https://api.github.com/users/ChicoXYC/events/public?page=2&per_page=100',
# ...

# %%
for url in url_list:
    time.sleep(2)
    try:
        commits = get_over_100(url)
        all_commits.extend(commits)
    except:
        print(url)
#maximum return with 300 entry.
# Out:
# https://api.github.com/users/hupili/events/public?page=4&per_page=100
# https://api.github.com/users/hupili/events/public?page=5&per_page=100
# https://api.github.com/users/hupili/events/public?page=6&per_page=100
# https://api.github.com/users/hupili/events/public?page=7&per_page=100
# https://api.github.com/users/hupili/events/public?page=8&per_page=100
# https://api.github.com/users/hupili/events/public?page=9&per_page=100
# https://api.github.com/users/hupili/events/public?page=10&per_page=100
# https://api.github.com/users/hupili/events/public?page=11&per_page=100
# https://api.github.com/users/ChicoXYC/events/public?page=4&per_page=100
# https://api.github.com/users/ChicoXYC/events/public?page=5&per_page=100
# https://api.github.com/users/ChicoXYC/events/public?page=6&per_page=100
# https://api.github.com/users/ChicoXYC/events/public?page=7&per_page=100
# https://api.github.com/users/ChicoXYC/events/public?page=8&per_page=100
# ...

# %%
len(all_commits)
# Out:
# 3194

# %%
url='https://api.github.com/users/hupili/events/public?page=4&per_page=100'

r = requests.get(url,headers={
'User-Agent':'Mozilla/5.0',
'Authorization':'token 97daf92ba8b9969bb31166a26cf8c148228a3035',
'Content-Type':'application/json',
'method':'GET',
'Accept':'application/json'
})
content = r.json()
commits = []
for item in content:
    commit = {}
    commit['users'] = item['actor']['login']
    commit['type'] = item['type']
    commits.append(commit)

all_commits.extend(commits)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-02f3bd8e056d> in <module>
#      12 for item in content:
#      13     commit = {}
# ---> 14     commit['users'] = item['actor']['login']
#      15     commit['type'] = item['type']
#      16     commits.append(commit)
#
# TypeError: string indices must be integers

# %%
content
#with maximum 300 entries, and didn't find useful solution.
# Out:
# {'message': 'In order to keep the API fast for everyone, pagination is limited for this resource. Check the rel=last link relation in the Link response header to see how far back you can traverse.',
#  'documentation_url': 'https://developer.github.com/v3/#pagination'}
